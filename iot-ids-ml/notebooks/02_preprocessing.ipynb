# %% [markdown]
# # 02 - Preprocessing
#
# Chay pipeline tien xu ly: clean, missing, encode, split, scale, SMOTE (chi tren train).

# %%
import sys, os
sys.path.append(os.path.abspath('..'))

from src.data.loader import load_raw_dataset
from src.data.preprocessing import run_preprocessing_pipeline

DATA_PATH = '../data/raw/EdgeIIoTset.csv'
LABEL_COL = 'Attack_label'  # xac nhan truoc

df = load_raw_dataset(DATA_PATH)
result = run_preprocessing_pipeline(df, label_col=LABEL_COL, apply_smote=True)
result.X_train.shape, result.X_test.shape

# %%
result.label_encoder.classes_
