# %% [markdown]
# # 04 - Evaluation
#
# So sanh cac model va truc quan hoa ket qua (Confusion Matrix, ROC Curve, Feature Importance, Model Comparison).

# %%
import sys, os
sys.path.append(os.path.abspath('..'))

from src.evaluation.metrics import summarize_results, select_best_model
from src.evaluation.visualization import (
    plot_confusion_matrix, plot_roc_curve, plot_model_comparison, plot_time_comparison
)

# Gia su 'results' da co tu notebook 03 (chay lai hoac import lai o day)

# %%
summary_df = summarize_results(results)
summary_df

# %%
best = select_best_model(results)
best.model_name, best.recall, best.f1

# %%
plot_model_comparison(summary_df, metric='f1')

# %%
plot_time_comparison(summary_df)
