# %% [markdown]
# # 01 - EDA (Exploratory Data Analysis)
#
# Khảo sát dataset Edge-IIoTset trước khi tiền xử lý: shape, kiểu dữ liệu, missing values, phân bố lớp, thống kê mô tả.

# %%
import sys, os
sys.path.append(os.path.abspath('..'))

from src.data.loader import load_raw_dataset, inspect_columns, guess_label_columns

DATA_PATH = '../data/raw/EdgeIIoTset.csv'  # cap nhat duong dan thuc te
df = load_raw_dataset(DATA_PATH)
df.shape

# %%
inspect_columns(df)

# %% [markdown]
# ## Gợi ý cột nhãn (cần xác nhận thủ công)

# %%
guess_label_columns(df)

# %% [markdown]
# ## Phân bố lớp (label column can duoc xac nhan truoc)

# %%
label_col = 'Attack_label'  # THAY bang ten cot nhan thuc te da xac nhan
df[label_col].value_counts()

# %% [markdown]
# ## Missing values

# %%
df.isna().sum().sort_values(ascending=False).head(20)
